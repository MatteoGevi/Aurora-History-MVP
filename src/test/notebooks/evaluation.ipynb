# %%
import os, json
from pathlib import Path
project_root = Path.cwd().parent.parent.parent  # Go up from notebooks/ -> test/ -> src/ -> project root
sys.path.insert(0, str(project_root))

from src.models import generate
from src.retrieval import get_section_content
from src.evaluation import evaluate_answer

# Cell 2: Test with real IDs and a sample answer
document_id = "05f00edd-731d-4512-863a-dea9ab48e512"
node_id = "h3-6-3-1__supervised-finetuning"

# Use a question from your assessment test
test_question = "What were the main causes of the French Revolution?"

# Sample student answer to evaluate
student_answer = """
The French Revolution was caused by several factors including economic crisis, 
social inequality between estates, and Enlightenment ideas challenging absolute monarchy.
The financial strain from wars and lavish spending led to heavy taxation on the Third Estate.
"""

# %%
evaluation_result = evaluate_answer(
    document_id=document_id,
    node_id=node_id,
    question=test_question,
    student_answer=student_answer
)

# Cell 4: Display results
print(json.dumps(evaluation_result, indent=2))

# Cell 5: Check key metrics
print(f"\nScore: {evaluation_result['total_score']}/{evaluation_result['max_score']}")
print(f"Percentage: {evaluation_result['percentage']}%")
print(f"Performance Level: {evaluation_result['performance_level']}")
# Out:
# ⏳ Evaluating with rubric...
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 evaluation_result = evaluate_answer(
#       2     document_id=document_id,
#       3     node_id=node_id,
#       4     question=test_question,
#       5     student_answer=student_answer
#       6 )
#       8 # Cell 4: Display results
#       9 print(json.dumps(evaluation_result, indent=2))
#
# File ~/Aurora-History-MVP/src/evaluation.py:86, in evaluate_answer(document_id, node_id, question, student_answer)
#      37     prompt = f"""You are an expert educator evaluating a student's answer using a structured rubric.
#      38
#      39 QUESTION: {question}
#    (...)     81 }}
#      82 """
#      84     print("⏳ Evaluating with rubric...\n")
# ---> 86     response = generate(prompt, max_tokens=800, temperature=0.3)
#      88     try:
# ...
