# %%
import os, requests, base64
from IPython.display import display, HTML
from supabase import create_client

supabase = create_client(os.environ["SUPABASE_URL"], os.environ["SUPABASE_SERVICE_ROLE_KEY"])

# Option A: direct download (keeps path secret from clients)
data = supabase.storage.from_("textbook").download("ai-engineering-...pdf")

# Option B: mint short-lived signed URL (give to client)
signed = supabase.storage.from_("textbook").create_signed_url(
    "ai-engineering-...pdf", expires_in=60  # seconds
)
os.environ["DATABASE_URL"] = "postgresql://postgres:YOUR_PASSWORD@db.YOUR_REF.supabase.co:5432/postgres"

SIGNED_URL = "https://hyktlmgolbfnqwaptkqy.supabase.co/storage/v1/object/sign/textbook/ai-engineering-building-applications-with-foundation-models.pdf?token=eyJraWQiOiJzdG9yYWdlLXVybC1zaWduaW5nLWtleV82OTc2NTQ2Mi05OWYzLTQyODMtYTRiZi03ZjI3MjhlMTEyZTMiLCJhbGciOiJIUzI1NiJ9.eyJ1cmwiOiJ0ZXh0Ym9vay9haS1lbmdpbmVlcmluZy1idWlsZGluZy1hcHBsaWNhdGlvbnMtd2l0aC1mb3VuZGF0aW9uLW1vZGVscy5wZGYiLCJpYXQiOjE3NTk2NzU5NTUsImV4cCI6MTc5MTIxMTk1NX0.ZhlDxxdTH8amUpYIuZSJY0oNwTwLqZu7k4wW0oqv_N4"  # your link from Storage (the one you sent me)
PDF_PATH = "textbook.pdf"

EMBED_MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"
VECTOR_DIM = 384
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 5
#       2 from IPython.display import display, HTML
#       3 from supabase import create_client
# ----> 5 supabase = create_client(os.environ["SUPABASE_URL"], os.environ["SUPABASE_SERVICE_ROLE_KEY"])
#       7 # Option A: direct download (keeps path secret from clients)
#       8 data = supabase.storage.from_("textbook").download("ai-engineering-...pdf")
#
# File /opt/anaconda3/lib/python3.12/os.py:714, in _Environ.__getitem__(self, key)
#     711     value = self._data[self.encodekey(key)]
#     712 except KeyError:
#     713     # raise KeyError with the original key value
# --> 714     raise KeyError(key) from None
#     715 return self.decodevalue(value)
#
# KeyError: 'SUPABASE_URL'

# %%
'''Supabase PDF Retrieval'''

with open(PDF_PATH, "rb") as f:
    b64 = base64.b64encode(f.read()).decode("utf-8")

html = f'''
<embed
  src="data:application/pdf;base64,{b64}"
  type="application/pdf"
  width="100%"
  height="800px"
/>
'''
display(HTML(f'<iframe src="{PDF_PATH}" width="100%" height="800px"></iframe>'))
# Out:
# /Users/matteogevi/Aurora-History-MVP/.venv/lib/python3.12/site-packages/IPython/core/display.py:447: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="textbook.pdf" width="100%" height="800px"></iframe>
